# %%
import pandas as pd

df = pd.read_csv("../data/raw/upworthy-archive-exploratory-packages-03.12.2020.csv", index_col=0)

print("shape:", df.shape)
print(df.groupby("clickability_test_id").size().describe())
print(df.groupby("clickability_test_id")[["created_at","excerpt","eyecatcher_id","test_week"]].nunique().max())
print(df.isnull().sum())
# Out:
# shape: (22666, 16)
# count    4873.000000
# mean        4.651344
# std         1.185801
# min         2.000000
# 25%         4.000000
# 50%         4.000000
# 75%         5.000000
# max        14.000000
# dtype: float64
# created_at       14
# excerpt          11
# eyecatcher_id    14
# test_week         2
# dtype: int64
# created_at                  0
# updated_at                  0
# clickability_test_id        0
# excerpt                  2417
# headline                    0
# lede                       12
# slug                        0
# eyecatcher_id              22
# impressions                 0
# clicks                      0
# significance                0
# first_place                 0
# winner                      0
# share_text              19458
# square                  15220
# test_week                   0
# dtype: int64
